# %% [markdown]
# > carregue o
#
# limpos\_final\.xlsm
#
#
# e faça o daf info pra ver os tipos

# %%
import pandas as pd

# Load the Excel file (first sheet by default) and show DataFrame info
file_path = '../../../Datasets/limpos_final.xlsm'

# Try to read all sheets to determine the correct one; if multiple, pick the first
xl = pd.ExcelFile(file_path)
sheet_name = xl.sheet_names[0]

df = pd.read_excel(file_path, sheet_name=sheet_name)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1341 entries, 0 to 1340
# Data columns (total 42 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Index_novo                        1341 non-null   int64
#  1   product_id                        1341 non-null   object
#  2   title_orig                        1341 non-null   object
#  3   price                             1341 non-null   float64
#  4   retail_price                      1341 non-null   int64
#  5   units_sold                        1341 non-null   int64
#  6   uses_ad_boosts                    1341 non-null   int64
#  7   rating                            1341 non-null   float64
#  8   rating_count                      1341 non-null   int64
#  9   rating_five_count                 1341 non-null   int64
#  10  rating_four_count                 1341 non-null   int64
# ...

# %% [markdown]
# > e mostra eles ue pro relatorio de nulos vazios,

# %%
df
# Out:
#       Index_novo                product_id  \
# 0              1  5e9ae51d43d6a96e303acdb0
# 1              2  58940d436a0d3d5da4e95a38
# 2              3  5ea10e2c617580260d55310a
# 3              4  5cedf17ad1d44c52c59e4aca
# 4              5  5ebf5819ebac372b070b0e70
# ...          ...                       ...
# 1336        1566  5e8f0165e815903d022a3c7c
# 1337        1568  5c91a7ae7cfe8e4e64c36d97
# 1338        1569  5d5fadc99febd9356cbc52ee
# 1339        1571  5e74be96034d613d42b52dfe
# 1340        1573  5e857321f53c3d2d8f25e7ed
#
#                                              title_orig  price  retail_price  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1      Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2     2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3     Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=acb13dac-3e3d-49c3-81b9-b25c403473b5' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
