# %%
import platform

versao_python = platform.python_version()

print(versao_python)
# Out:
# 3.13.9

# %%
import sys

caminho_do_python = sys.executable

print(caminho_do_python)
# Out:
# /opt/homebrew/anaconda3/bin/python

# %%
#!pip list --format=freeze
